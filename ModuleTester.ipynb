# %%
import sys
from util import tool

# %%
inim = '/data4/gecko/test/Calib-LOAO-NGC6070-20230421-113832-R-180.com.fits'
refim = '/data4/gecko/test/Ref-LOAO-NGC6070-0-0-R-0.fits'

# %%
tool.gregistering(
    images_to_align=[refim],
    ref_image=inim,
)
# Out:
# ##########  Preparing reference ...
# No filter file found, using default filter
# No NNW file found, using default NNW config
# >
# ----- SExtractor 2.19.5 started on 2023-04-25 at 19:37:17 with 1 thread
#
# > Setting catalog parameters
# > Reading detection filter
# > Initializing catalog
# > Looking for Calib-LOAO-NGC6070-20230421-113832-R-180.com.fits
# ----- Measuring from: Calib-LOAO-NGC6070-20230421-113832-R-180.com.fits
#       "NGC6070" / no ext. header / 2048x2048 / 32 bits (floats)
# Detection+Measurement image: > Setting up background maps
# > Setting up background map at line:   64
# > Setting up background map at line:  128
# > Setting up background map at line:  192
# > Setting up background map at line:  256
# > Setting up background map at line:  320
# > Setting up background map at line:  384
# > Setting up background map at line:  448
# > Setting up background map at line:  512
# > Setting up background map at line:  576
# > Setting up background map at line:  640
# ...
